# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import numpy as np
import html5lib
import os
import glob

# %%
# URL API CoinGecko
url = "https://api.coingecko.com/api/v3/coins/markets"

# Paramètres de la requête
params = {
    "vs_currency": "usd",
    "order": "market_cap_desc",  # Tri par capitalisation décroissante
    "per_page": 60,              # 50 premières cryptos
    "page": 1,
    "sparkline": False
}

# Requête GET
response = requests.get(url, params=params)
data = response.json()


for i in data:
    info_crypto = (i["name"], i["symbol"], i["current_price"],i["market_cap"], i["total_volume"], i["circulating_supply"],i["ath"],i["last_updated"])
    #print(info_crypto)


df = pd.DataFrame()
df["Short_Name_Cryptos"] = [i["name"] for i in data]
df["Ticker_cryptos_Yf"] = [i["symbol"].upper()+ "-USD" for i in data]
df["Ticker_Cryptos"] = [i["symbol"] for i in data]
df["Prix_actuel"] = [i["current_price"] for i in data]
df["Capitalisation_Boursiere"] = [i["market_cap"] for i in data]
df["Offre_En_Circulation"] = [i["circulating_supply"] for i in data]
df["ATH"] = [i["ath"] for i in data]
df["MAJ"] = [i["last_updated"].split("T")[0] for i in data]

display(df)

 # Sauvegarde du fichier
df.to_csv(("csv/csv_bdd/crypto_infos.csv"),)
# Out:
#                                    Short_Name_Cryptos Ticker_cryptos_Yf  \
# 0                                             Bitcoin           BTC-USD
# 1                                            Ethereum           ETH-USD
# 2                                              Tether          USDT-USD
# 3                                                 XRP           XRP-USD
# 4                                                 BNB           BNB-USD
# 5                                              Solana           SOL-USD
# 6                                                USDC          USDC-USD
# 7                                   Lido Staked Ether         STETH-USD
# 8                                                TRON           TRX-USD
# 9                                            Dogecoin          DOGE-USD
# 10                                            Cardano           ADA-USD
# 11                                      Wrapped stETH        WSTETH-USD
# 12                                    Wrapped Bitcoin          WBTC-USD
# 13                                       Figure Heloc    FIGR_HELOC-USD
# 14                                 Wrapped Beacon ETH         WBETH-USD
# 15                                          Chainlink          LINK-USD
# 16                                        Hyperliquid          HYPE-USD
# 17                                       Bitcoin Cash           BCH-USD
# 18                                       Wrapped eETH         WEETH-USD
# 19                                               USDS          USDS-USD
# 20                                            Stellar           XLM-USD
# 21                                        Ethena USDe          USDE-USD
# 22             Binance Bridged USDT (BNB Smart Chain)       BSC-USD-USD
# 23                                          LEO Token           LEO-USD
# 24                                               WETH          WETH-USD
# 25                                                Sui           SUI-USD
# 26                                      WhiteBIT Coin           WBT-USD
# 27                                             Hedera          HBAR-USD
# 28                               Coinbase Wrapped BTC         CBBTC-USD
# 29                                          Avalanche          AVAX-USD
# 30                                           Litecoin           LTC-USD
# 31                                              Zcash           ZEC-USD
# 32                                             Monero           XMR-USD
# 33                                          Shiba Inu          SHIB-USD
# 34                                            Toncoin           TON-USD
# 35                                              USDT0         USDT0-USD
# 36                                 Ethena Staked USDe         SUSDE-USD
# 37                                             Cronos           CRO-USD
# 38                                                Dai           DAI-USD
# 39                                          Bittensor           TAO-USD
# 40                                           Polkadot           DOT-USD
# 41                                             Mantle           MNT-USD
# 42                                           MemeCore             M-USD
# 43                                              sUSDS         SUSDS-USD
# 44                            World Liberty Financial          WLFI-USD
# 45                                               Aave          AAVE-USD
# 46                                            Uniswap           UNI-USD
# 47                                       Bitget Token           BGB-USD
# 48                                               USD1          USD1-USD
# 49                                                OKB           OKB-USD
# 50  BlackRock USD Institutional Digital Liquidity ...         BUIDL-USD
# 51                                         PayPal USD         PYUSD-USD
# 52                                               Pepe          PEPE-USD
# 53                                      NEAR Protocol          NEAR-USD
# 54                                             Ethena           ENA-USD
# 55                                    Jito Staked SOL       JITOSOL-USD
# 56                                   Ethereum Classic           ETC-USD
# 57                                        Wrapped SOL           SOL-USD
# 58                                   Binance-Peg WETH          WETH-USD
# 59                                              Aptos           APT-USD
#
#    Ticker_Cryptos    Prix_actuel  Capitalisation_Boursiere  \
# 0             btc  107484.000000             2146070426142
# 1             eth    3698.040000              447070715379
# 2            usdt       1.000000              183460057302
# 3             xrp       2.400000              144458986627
# 4             bnb    1009.570000              139176167606
# 5             sol     175.050000               96736877797
# 6            usdc       0.999705               75764479963
# 7           steth    3699.970000               31845945862
# 8             trx       0.293190               27757511366
# 9            doge       0.173592               26348466833
# 10            ada       0.575653               21069445373
# 11         wsteth    4506.210000               15067243388
# 12           wbtc  107470.000000               13624320302
# 13     figr_heloc       1.017000               13615786436
# 14          wbeth    4001.010000               13060460114
# 15           link      16.020000               11169560170
# 16           hype      41.160000               11133851507
# 17            bch     522.820000               10428414443
# 18          weeth    3994.380000                9816412456
# 19           usds       0.999461                9560886476
# 20            xlm       0.291219                9338313239
# 21           usde       0.998770                9258983565
# 22        bsc-usd       0.999467                8979424627
# 23            leo       9.580000                8832252035
# 24           weth    3701.360000                8216692734
# 25            sui       2.180000                8043312231
# 26            wbt      54.600000                7869990284
# 27           hbar       0.182167                7741398732
# 28          cbbtc  107486.000000                7712607819
# 29           avax      17.440000                7444680720
# 30            ltc      92.100000                7052491995
# 31            zec     391.650000                6415107098
# 32            xmr     347.270000                6405537583
# 33           shib       0.000010                5657486237
# 34            ton       2.200000                5464736680
# 35          usdt0       0.999330                5321232908
# 36          susde       1.200000                4994244120
# 37            cro       0.135923                4906009117
# 38            dai       0.999316                4550583540
# 39            tao     472.400000                4540427705
# 40            dot       2.760000                4201857926
# 41            mnt       1.280000                4180305232
# 42              m       2.350000                3986927387
# 43          susds       1.080000                3748126865
# 44           wlfi       0.123914                3380210115
# 45           aave     212.090000                3237373724
# 46            uni       5.380000                3233554317
# 47            bgb       4.280000                2997350454
# 48           usd1       0.999161                2984668056
# 49            okb     135.310000                2840896836
# 50          buidl       1.000000                2828736997
# 51          pyusd       0.999947                2814973351
# 52           pepe       0.000006                2574481398
# 53           near       2.000000                2561335432
# 54            ena       0.353217                2527677375
# 55        jitosol     217.430000                2476279298
# 56            etc      15.290000                2359417133
# 57            sol     174.930000                2283093574
# 58           weth    3695.730000                2241425737
