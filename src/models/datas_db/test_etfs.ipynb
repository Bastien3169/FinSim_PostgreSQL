# %%
import pandas as pd

df = pd.read_csv("/Users/bastoch/app_Finance_Project/ProjectFinance_Streamlit_new/csv/csv_bdd/etfs_infos.csv")

df = df.sort_values("Volume_Moyen", ascending=False)
df = df.drop_duplicates(subset="Short_Name_Etf", keep="first")

df.to_csv(("/Users/bastoch/app_Finance_Project/ProjectFinance_Streamlit_new/csv/csv_bdd/etfs_infos.csv"), index=False, encoding="utf-8")

# %%
import pandas as pd

df = pd.read_csv("/Users/bastoch/app_Finance_Project/ProjectFinance_Streamlit_new/csv/csv_bdd/cryptos_infos.csv")

print(list(df.columns))

nb_total = df["Ticker_cryptos_Yf"].shape[0]
nb_uniques = df["Ticker_cryptos_Yf"].nunique()

display(df[df["Ticker_cryptos_Yf"].duplicated(keep=False)])


df = df.drop_duplicates(subset="Ticker_cryptos_Yf", keep="first")

display(df[df["Ticker_cryptos_Yf"].duplicated(keep=False)])

#df.to_csv(("/Users/bastoch/app_Finance_Project/ProjectFinance_Streamlit_new/csv/csv_bdd/cryptos_infos.csv"), index=False, encoding="utf-8")
# Out:
# ['Short_Name_Cryptos', 'Ticker_cryptos_Yf', 'Ticker_Cryptos', 'Prix_actuel', 'Capitalisation_Boursiere', 'Offre_En_Circulation', 'ATH', 'MAJ']
# Empty DataFrame
# Columns: [Short_Name_Cryptos, Ticker_cryptos_Yf, Ticker_Cryptos, Prix_actuel, Capitalisation_Boursiere, Offre_En_Circulation, ATH, MAJ]
# Index: []
# Empty DataFrame
# Columns: [Short_Name_Cryptos, Ticker_cryptos_Yf, Ticker_Cryptos, Prix_actuel, Capitalisation_Boursiere, Offre_En_Circulation, ATH, MAJ]
# Index: []
